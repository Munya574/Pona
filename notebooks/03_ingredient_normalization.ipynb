# %% [markdown]
# # Ingredient Normalization Model
#
# Fine-tune DistilBERT (or build a spaCy pipeline) to map raw ingredient text to standardized entities.
#
# Examples:
# - 'sodium caseinate' → dairy derivative
# - 'hydrolyzed wheat protein' → gluten source
# - 'groundnuts' → peanuts

# %%
# TODO: load training data from Open Food Facts + USDA FoodData Central
# Build entity mapping and fine-tune DistilBERT
