# %% [markdown]
# # Food-101 Dataset Exploration
#
# Explore the Food-101 dataset (101,000 images, 101 categories) used for CV model training.

# %%
# TODO: load Food-101 from Hugging Face datasets
# from datasets import load_dataset
# ds = load_dataset('food101')
