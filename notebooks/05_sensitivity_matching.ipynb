# %% [markdown]
# # Sensitivity Matching Engine
#
# Build the rule-based + ML ranking engine that maps normalized ingredients to sensitivity triggers.
#
# Knowledge base sources:
# - FARE allergen data
# - NHS guidelines
# - Published elimination diet research
# - USDA FoodData Central
#
# Vector store: FAISS for RAG-based retrieval.

# %%
# TODO: build sensitivity_kb JSON, index into FAISS, evaluate matching accuracy
